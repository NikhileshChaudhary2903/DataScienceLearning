# %%
import numpy as np
import pandas as pd
from google.cloud import bigquery
from bq_helper import BigQueryHelper
# %load_ext google.cloud.bigquery
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="My Project-bbdce7b1712b.json"
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
bq_assistant = BigQueryHelper("bigquery-public-data", "epa_historical_air_quality")

Querygreaterthan_2008="""SELECT * FROM `bigquery-public-data.epa_historical_air_quality.air_quality_annual_summary`
where state_name ="California" and year >=2008 """

df = bq_assistant.query_to_pandas(Querygreaterthan_2008)

# %%
df
# Out:
#        state_code county_code site_num  parameter_code  poc   latitude  \
# 0              06         041     2001           84313    1  38.015136
# 1              06         041     2001           84313    1  38.015136
# 2              06         041     2001           84313    1  38.015136
# 3              06         041     2001           84313    1  38.015136
# 4              06         041     2001           84313    1  38.015136
# 5              06         017     0011           61103    3  38.944979
# 6              06         017     0011           61103    3  38.944979
# 7              06         017     0011           61103    2  38.944979
# 8              06         017     0011           61103    3  38.944979
# 9              06         017     0011           61103    2  38.944979
# 10             06         017     0011           61103    2  38.944979
# 11             06         017     0011           61103    2  38.944979
# ...
